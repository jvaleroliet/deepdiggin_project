# %% [markdown]
# # Data Annotation
# Let's annotate the data we collected. The audio condition is on a string that we have to read and label manually. Some conventions used:
#
# - We interpreted VG- as G+, E as VG+, E- as VG+.
#
# - We only labelled the first side.
#
# - We only labeled the first part in case of improvement of the vinyl condition in the same side.
#
# We will use the excelent pigeon tool.

# %%
import pandas as pd
from pigeon import annotate

# %%
wills_audio = pd.read_csv("./output/wills_audio.csv")
wills_audio.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  http://www.watchcount.com/go/?item=11623035299...
# 1           1  http://www.watchcount.com/go/?item=11623035299...
# 2           2  http://www.watchcount.com/go/?item=11623035039...
# 3           3  http://www.watchcount.com/go/?item=11623034962...
# 4           4  http://www.watchcount.com/go/?item=11623034725...
#
#                                                Title  \
# 0  Ahmed al-Jaberi - Rare SUDAN Arabic Afro 45 / ...
# 1  Ahmed al-Jaberi - Rare SUDAN Arabic Afro 45 / ...
# 2  Mohamed Mirghani - Rare SUDAN Arabic Afro 45 /...
# 3  Tayeb Abdullah ? - Rare SUDAN Arabic Afro 45 /...
# 4  Ibrahim Awad - Ya Zaman - Rare SUDAN Arabic Af...
#
#                                            condition                  mp3_path
# 0                                                NaN                       NaN
# 1  :&nbsp;\u003C/b><span style=\"font-family: Ari...  ./output/audio2/7595.mp3
# 2  :&nbsp;\u003C/b><span style=\"font-family: Ari...  ./output/audio2/5576.mp3
# 3  :&nbsp;\u003C/b><span style=\"font-family: Ari...  ./output/audio2/7000.mp3
# 4  :&nbsp;\u003C/b><span style=\"font-family: Ari...  ./output/audio2/4374.mp3

# %% [markdown]
# Let's initialize the annotator and make the boring part!

# %%
annotations = annotate(
  wills_audio.condition.tolist(),
  options=['M', "NM", "VG+", "VG", "G+", "G", "F"])
# Out:
# HTML(value='0 examples annotated, 379 examples left')
# Dropdown(options=('M', 'NM', 'VG+', 'VG', 'G+', 'G', 'F'), value='M')
# HBox(children=(Button(description='submit', style=ButtonStyle()), Button(description='skip', style=ButtonStyle…
# Output()
# Annotation done.

# %% [markdown]
# Let's have a look on the annotations.

# %%
annotations
# Out:
# [(':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , see pics for label ',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ visually, playing VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , light marks and improving.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ visual. Plays more VG+ , see pics for label ',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks! See pics\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See pics\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See pics/\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See label pics at top.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG / VG , no skips, pen name on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Couple of small tics occasionally.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Other side has a sticker removal mark top of label.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. see pics of labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. see pics of labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG+ , heavy funky B side heard second in the clip. Quiet pressing.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG / VG , B heard first in the soundclip. Small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG no skips. Plays great.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks only\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- no skips. Check full clip. Tiny pen mark on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips.&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , though there was a stick at the end of side B (10:55 in clip)\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , see pics for label ',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , great copy. Side B is very slightly off-centre.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , messy pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, great copy. Messy pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , messy pen on labels, see pics.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , messy pen on labels, see pics.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Small pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / G+ , no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Shop stamp on A side label.&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+ , great copy. Small pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+ , great copy. Small pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Small pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Small pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , don\'t miss the disco style B side.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , small pen on labels\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ visual. Stick end of A side (no visual marks). Small stamp on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , both labels are a bit stained/discoloured.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX-\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , slight fading/wear to labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , dirt/worn both labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , dirt/worn B side label, stamped.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , slight hazing and minor warp to edge side 2, not affecting play. Pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G visual. Plays G+ , 1 stick end of the B side.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips, plays loud.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ (first 30-60s) to VG , no skips. Tiny pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips. Stamp on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Pen on both labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / G+ to VG- , no skips, plays well. Clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very unusual side B don\'t miss the clip!\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX , sample stamp on side B label\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , sample stamp on side B&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Plays decently though, check longer clip. Small pen on labels.&nbsp;\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG+ / VG to VG+ , no skips. Few little scuffs start of first side in clip. Small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ . Small pen name on labels\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips. poor labels , other side label is worse.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , other side label is more faded, little pen marks.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G visual, the play grade is G+ though and is punchy and loud despite marks.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Quiet pressing especially the \'Guaguanco\' side\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ visual , plays VG- . Name sticker top of B side.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen name on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Pressing quality is a bit muffled on other side. Messy pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- (first 30-60s) to VG+ , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG to VG+ , small pen name on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , some light marks and improving. Clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX stock\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ / G+ , no skips. B heard first in clip, clean labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , nice labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , the text has faded a bit on both sides.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX stock\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear... no skips. Worn labels.\\u003C',
#   'F'),
#  (' (visual and partial audio grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , see label pics&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;Mostly NM unplayed , however there\'s a little bit of paper stuck in pressing at start of A side (see 2nd pic) causing a few tics, and also a smaller piece stuck in the B side that causes a few lighter tics (listen at 2:08 in clip, it\'s very mild).\\u003C',
#   'NM'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX , unplayed stock copy.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, shiny copy clean looking, a few little tiny marks, plays fine, clean labels.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;shiny and clean, few little tiny marks in places , grade VG to VG+\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp; &nbsp;, no skips. Small pen name on B label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG. Small pen on labels.&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , there was a little piece of dirt at 0:45 in clip that is now clear.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips, plays loud, see pics of labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Messy pen both labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ / VG- as per the clip, see label pics, no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips. Messy pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG , no skips. Labels worn, little pen and some light flaking.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG- to VG\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG+\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- plays great more of a VG sound quality.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Pressing has noise on it. Pen on labels. NOTE: no skip at end of the clip, I nudged the deck by accident.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , noise on pressing, B side playing very slightly off-centre\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some noise on pressing.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy. Small pen on B label.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Slight pressing noise.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , some marks and scuffs. Labels have some wear.&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some noise on pressing. Nice copy!&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , nice labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , pen marks on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , labels faded/worn both sides\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean.&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only.&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only.&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only , coloured vinyl. Small writing on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- first 30s , then improving to VG+\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , some label wear.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some superficial marks\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some noise on pressing on A side.&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Small pen mark on one label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG / VG , side B heard first in clip. No skips, there is a few pops from a little mark near start of side A which is why the grade is lower at the start of the side. Label wear and little label rips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ / fair , no skips. Side 2 has some feelable marks. Staining to B side label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Labels worn and top part ripped with stamped number both sides, SWOL\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels decent\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , clean copy with a few superficial marks.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some wear to both labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some superficial marks only\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / VG , B heard first in clip. See label pics.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , no skips, loud pressing. See label pics.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;A is G+ to VG- / B is VG- , no skips. Side B heard first in clip.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. See label pics.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , clean copy with a few superficial marks. Slight label flaking.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , shiny with little marks and scuffs. See label pics. Side B heard first in clip.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ (except first 10-20s each side maybe a few marks VG)\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels worn (see pics)&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ a few superficial marks only.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels damaged both sides at the top.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some wear to the labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp; , some superficial marks only. Messy pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , no skips, nice pressing plays loud, small pen on B label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays with light noise other side.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips, nice labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG play grade. Labels worn.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;A1-A2 is VG, then VG+ rest side A. Side B1 (listen at 2:00 in clip) is G+ has a few scuffs causing occasional pops/tics and 1 skip (at 2:54 in clip). B2 VG , then rest of side B VG+ light traces. Clean labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ clean copy, superficial marks only.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Loud pressing.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , quite heavy wear, plays fine despite marks, no skips.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX / VG+ to EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ (there was a little dirt that is now cleared and there is no longer a skip as shows in clip at 1:52)\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG / VG , no skips. B heard first in audio clip, nice clean labels except small pen name top of A side label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , pen name on both labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small blue marker pen name on other side\'s label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , clean labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips , small&nbsp;\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , small pen on labels and other side label worn.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , quite heavy wear, plays loud and still sounds decent. Small pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, heavy wear, plays without skips.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, nice labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips, marks and scuffs and improving. Decent labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips, heavy wear, plays through fine more G+ sonically.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips, heavy wear, plays through fine. SWOL\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips. No pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Dirty labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG , no skips. Pen titles on both sides labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, messy pen on labels. Some subtle (quiet) strange high noise on side 2 on the pressing.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen name on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen name on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , clean labels.&nbsp;\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Nice labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , few little very minor marks start of each side\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ bordering EX , super nice copy EXCEPT one tiny scuff on the less funky side (heard 1:07-1:20 in clip) causes a few repeat tics/pops. Check label pics.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX , see pics for label ',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , nice copy, playing fair clean and the A side playing above grade. Clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , nice copy, more sound quality. Clean labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy light marks and improving plays quite clean and nice, check label photos.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , no skips\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX / EX-\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX-\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX- , see pics for labels\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+ , one small mark first 1-2 mins side B lowers grade a tiny bit.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;poor / fair , side A has several large sideways scratches that cause repeat skips/sticks, side B is around the G+ grade but also has sticks/skips due to several marks so I didn\'t listen to the whole side.\\u003C',
#   'F'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ ,see pics for labels&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+, superficial marks.. See label pics. NOTE this release has a slightly distorted sound on ALL the pressings I have heard, there is no \'clipping\' on my sound file.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear... though it plays through fine with no skips (there was a stick at end of A in the audio clip that is now cleared). Worn labels.\\u003C',
#   'F'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips. clean labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , bit noisy on the run-in then plays G+ no skips. Small pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skip, small pen marks both sides.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G no skips heard, worn labels with small pen.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG- to VG , clean labels except 1 small white mark side B label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp; , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Tiny pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;intro/start of A G , then it\'s G+ sound quality all the way after that , has marks and scuffs but plays fine without skips. Clean labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG light marks, no skips.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ (first 30s) moving gradually to VG, no skips. Pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; G visual very worn and scratched , but plays loud more like G+ , no skips.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; first 30-60s each side G+ some scuffing moving to VG+ after that. Messy pen on both labels.\\u003C',
#   'G+'),
#  (' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, many marks and scuffs, may have skips/sticks.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ , small pen on the A label, B label clean.\\u003C',
#   'VG+'),
#  (' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , may have skips.&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG, light marks. Small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ , a few superficial fait marks only. Small pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , plays fine, no skips, faint stamp and marker pen initials on both labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, pen on other side label.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG- to VG+ as per the clip, small pen name on labels and label wear around the edges.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, small pen name on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG (30 seconds) to VG+ , small pen on labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , except a couple little scuffs heard at the start of the first song in clip.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;Side A plays G (first 60s) then gradually improves up to about a VG- grade. Side B similar but improves faster playing G+ after about 30s then gradually improving to VG-. Clean labels.&nbsp;\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , nice clean copy, messy pen on both labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG both sides, no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on both labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , great copy. Small pen name both sides\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ / G , no skips. Clean labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG , light marks, clean labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , noisy at the start and improving, no skips, pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , small pen on B label\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG-, no skips, pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+ bordering EX.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+ , slight hazing to the A side&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , clean labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , though a small mark causes a stick middle of side 2 (check 0:39 in clip)\\u003C',
#   'VG'),
#  (' (visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;poor - very heavy wear, pretty much unplayable. It\'s a filler copy. See pictures for label ',
#   'F'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , don\'t miss the killer B side !! at 3:12 in clip.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips heard, pen on labels. Side 2 looks quite bad but still plays fine.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, side B dull colour, doesn\'t seem to affect play. Small pen on labels.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG- to VG+&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ (skip at 1:01 has now been cleared)\\u003C',
#   'VG'),
#  (' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG- , numerous light marks and scuffs both sides, nothing major. Check extended clip, sounds quality nice. Small pen name on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;FAIR , heavy wear... didn\'t hear any skips... Pen on labels.\\u003C',
#   'F'),
#  (' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG- to VG , except B1 G+ , clean labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG\\u003C',
#   'G+'),
#  (' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , numerous little marks and scuffs and improving. Pen small on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, small pen on labels (2 skips heard between 0:49-0:55 have now been cleared)\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, pen on labels , B side is the killer side don\'t miss it in the clip\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;visually G+ on side A plays VG- , side B \\"La Murga\\" plays VG- to VG\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+. Small pen on B label.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen on labels.&nbsp;&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;plays VG to VG+&nbsp;&nbsp;\\u003C',
#   'VG'),
#  (' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Light label wear/staining&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.&nbsp;&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , small pen on labels.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ ,small pen on B label.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+, small sticker on B label.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, clean labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, small sticker on B label\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks, small pen on B label. Great ballad B side!\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays at 33rpm\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG&nbsp;\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG (30s) to VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , other side has a bit of pen on label\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear! side heard first in the clip has NO skips and plays better than it looks after the first 30s, the other sides has skips/sticks.\\u003C',
#   'F'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , B heard first in clip - check the surprise rap at 2:22 in the clip !\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays with some light noise.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , sample stamp on B label\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , faint sample stamp.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , faint sample stamp.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks.\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; first 30s VG moving to VG+&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; first 30s VG moving to VG+ . Clean labels.\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG , light marks.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG , light marks.&nbsp;\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ no skips. Very messy pen on both labels!\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+&nbsp;\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , smal pen on labels\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- no skips, a few little noises from circular wear middle side 2. Labels a bit worn.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ / G+ as per the clip. no skips\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , no skips, plays loud.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- no skips. Small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- , more VG- , no skips, small pen on labels.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips... Heavy wear both sides but playing fine on the second half. WOL\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; EX / VG+ to EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , no skips\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , small pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ no skips, numerous little marks and scuffs, plays loud.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips. Pen on labels.\\u003C',
#   'G'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ first 30s then VG- both sides.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG, light marks. Slight haze to vinyl\\u003C',
#   'VG'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ visual, plays VG- no skips.\\u003C',
#   'G+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C',
#   'VG+'),
#  (':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; &nbsp; &nbsp;G+ to VG- 1 skip heard side 1. EDGE CHIP second photo, doesn\'t affect play unless you have an automatic turntable. Sticker residue marks on labels.\\u003C',
#   'G+')]

# %% [markdown]
# Let's remove duplicates.

# %%
annotations = list(set(annotations))

# %% [markdown]
# Let's convert to some more readeable format.

# %%
def convert(tup, dictionary):
    for a, b in tup:
        dictionary.setdefault(a, []).append(b)
    return dictionary

dictionary = {}

dictionary = convert(annotations, dictionary)

# %%
dictionary
# Out:
# {':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some noise on pressing.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , slight fading/wear to labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp; &nbsp;, no skips. Small pen name on B label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG both sides, no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ / G , no skips. Clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , both labels are a bit stained/discoloured.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG- to VG , clean labels except 1 small white mark side B label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+ , slight hazing to the A side&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , bit noisy on the run-in then plays G+ no skips. Small pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Small pen mark on one label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , some label wear.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , slight hazing and minor warp to edge side 2, not affecting play. Pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG- to VG\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G visual, the play grade is G+ though and is punchy and loud despite marks.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ bordering EX , super nice copy EXCEPT one tiny scuff on the less funky side (heard 1:07-1:20 in clip) causes a few repeat tics/pops. Check label pics.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, small pen name on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ visual , plays VG- . Name sticker top of B side.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG- to VG+&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Shop stamp on A side label.&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+, superficial marks.. See label pics. NOTE this release has a slightly distorted sound on ALL the pressings I have heard, there is no \'clipping\' on my sound file.\\u003C': ['VG+'],
#  ' (visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;poor - very heavy wear, pretty much unplayable. It\'s a filler copy. See pictures for label ': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays with some light noise.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Light label wear/staining&nbsp;\\u003C': ['VG'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG- , numerous light marks and scuffs both sides, nothing major. Check extended clip, sounds quality nice. Small pen name on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX- , see pics for labels\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen on labels.&nbsp;&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , don\'t miss the disco style B side.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;Mostly NM unplayed , however there\'s a little bit of paper stuck in pressing at start of A side (see 2nd pic) causing a few tics, and also a smaller piece stuck in the B side that causes a few lighter tics (listen at 2:08 in clip, it\'s very mild).\\u003C': ['NM'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ (first 30-60s) to VG , no skips. Tiny pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Tiny pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , great copy. Small pen name both sides\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen name on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays at 33rpm\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips, plays loud.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Labels worn and top part ripped with stamped number both sides, SWOL\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. See label pics.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG play grade. Labels worn.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , B heard first in clip - check the surprise rap at 2:22 in the clip !\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;poor / fair , side A has several large sideways scratches that cause repeat skips/sticks, side B is around the G+ grade but also has sticks/skips due to several marks so I didn\'t listen to the whole side.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, pen on labels , B side is the killer side don\'t miss it in the clip\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips. Pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX , sample stamp on side B label\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX stock\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels decent\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small blue marker pen name on other side\'s label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; first 30s VG moving to VG+ . Clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ no skips, numerous little marks and scuffs, plays loud.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG / VG , side B heard first in clip. No skips, there is a few pops from a little mark near start of side A which is why the grade is lower at the start of the side. Label wear and little label rips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , other side has a bit of pen on label\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , smal pen on labels\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy light marks and improving plays quite clean and nice, check label photos.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some superficial marks only\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG , no skips. Labels worn, little pen and some light flaking.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , some light marks and improving. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;plays VG to VG+&nbsp;&nbsp;\\u003C': ['VG'],
#  ' (visual and partial audio grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , see label pics&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , quite heavy wear, plays loud and still sounds decent. Small pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Couple of small tics occasionally.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some noise on pressing on A side.&nbsp;\\u003C': ['VG+'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, many marks and scuffs, may have skips/sticks.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips. poor labels , other side label is worse.\\u003C': ['G'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG- to VG , except B1 G+ , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips , small&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , few little very minor marks start of each side\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , pen marks on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ visually, playing VG+&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips, heavy wear, plays through fine more G+ sonically.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skip, small pen marks both sides.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp; , some superficial marks only. Messy pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very unusual side B don\'t miss the clip!\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX-\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , messy pen on labels, see pics.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG. Small pen on labels.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels worn (see pics)&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , small pen on B label\\u003C': ['G'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , may have skips.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks, small pen on B label. Great ballad B side!\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean.&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG / VG , no skips. B heard first in audio clip, nice clean labels except small pen name top of A side label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , labels faded/worn both sides\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / G+ , no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , shiny with little marks and scuffs. See label pics. Side B heard first in clip.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG, light marks. Small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , nice clean copy, messy pen on both labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , small pen on labels\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , no skips\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , messy pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Quiet pressing especially the \'Guaguanco\' side\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, great copy. Messy pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;visually G+ on side A plays VG- , side B \\"La Murga\\" plays VG- to VG\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Slight pressing noise.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;shiny and clean, few little tiny marks in places , grade VG to VG+\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG , light marks.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , no skips, plays loud.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp; , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+. Small pen on B label.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips, marks and scuffs and improving. Decent labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , small pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ visual. Stick end of A side (no visual marks). Small stamp on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.&nbsp;&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ / VG- as per the clip, see label pics, no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Dirty labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips, plays loud, see pics of labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG / VG , B heard first in the soundclip. Small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only.&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels damaged both sides at the top.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ visual, plays VG- no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , great copy. Side B is very slightly off-centre.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ / G+ , no skips. B heard first in clip, clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, messy pen on labels. Some subtle (quiet) strange high noise on side 2 on the pressing.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+ bordering EX.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; first 30-60s each side G+ some scuffing moving to VG+ after that. Messy pen on both labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ (except first 10-20s each side maybe a few marks VG)\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ clean copy, superficial marks only.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks! See pics\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , pen name on both labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, small pen on labels (2 skips heard between 0:49-0:55 have now been cleared)\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , light marks and improving.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;A1-A2 is VG, then VG+ rest side A. Side B1 (listen at 2:00 in clip) is G+ has a few scuffs causing occasional pops/tics and 1 skip (at 2:54 in clip). B2 VG , then rest of side B VG+ light traces. Clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, shiny copy clean looking, a few little tiny marks, plays fine, clean labels.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG-, no skips, pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy. Small pen on B label.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG (30 seconds) to VG+ , small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, heavy wear, plays without skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear... though it plays through fine with no skips (there was a stick at end of A in the audio clip that is now cleared). Worn labels.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , faint sample stamp.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+, small sticker on B label.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips. clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, side B dull colour, doesn\'t seem to affect play. Small pen on labels.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG no skips. Plays great.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ (first 30s) moving gradually to VG, no skips. Pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ visual. Plays more VG+ , see pics for label ': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , don\'t miss the killer B side !! at 3:12 in clip.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG+ / VG to VG+ , no skips. Few little scuffs start of first side in clip. Small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG+ , heavy funky B side heard second in the clip. Quiet pressing.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G no skips heard, worn labels with small pen.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , dirt/worn both labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG (30s) to VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips. Messy pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Loud pressing.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- no skips, a few little noises from circular wear middle side 2. Labels a bit worn.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ first 30s then VG- both sides.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , though a small mark causes a stick middle of side 2 (check 0:39 in clip)\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , plays fine, no skips, faint stamp and marker pen initials on both labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on both labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , clean copy with a few superficial marks.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , clean copy with a few superficial marks. Slight label flaking.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , sample stamp on side B&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ , small pen on the A label, B label clean.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ ,small pen on B label.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , noise on pressing, B side playing very slightly off-centre\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , quite heavy wear, plays fine despite marks, no skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; first 30s VG moving to VG+&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks only\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX , unplayed stock copy.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear... no skips. Worn labels.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some noise on pressing. Nice copy!&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- first 30s , then improving to VG+\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG , no skips. Pen titles on both sides labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ no skips. Very messy pen on both labels!\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ . Small pen name on labels\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ a few superficial marks only.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ / G+ as per the clip. no skips\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- no skips. Small pen on labels.\\u003C': ['G+'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;intro/start of A G , then it\'s G+ sound quality all the way after that , has marks and scuffs but plays fine without skips. Clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear! side heard first in the clip has NO skips and plays better than it looks after the first 30s, the other sides has skips/sticks.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , some marks and scuffs. Labels have some wear.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+ , great copy. Small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some superficial marks\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ , a few superficial fait marks only. Small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX / EX-\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See pics/\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ ,see pics for labels&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- , more VG- , no skips, small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips... Heavy wear both sides but playing fine on the second half. WOL\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX / VG+ to EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Pen on both labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , nice copy, playing fair clean and the A side playing above grade. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG, light marks. Slight haze to vinyl\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G visual. Plays G+ , 1 stick end of the B side.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , see pics for label ': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See label pics at top.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Other side has a sticker removal mark top of label.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ (skip at 1:01 has now been cleared)\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays with light noise other side.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG to VG+ , small pen name on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , sample stamp on B label\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See pics\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips, heavy wear, plays through fine. SWOL\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; &nbsp; &nbsp;G+ to VG- 1 skip heard side 1. EDGE CHIP second photo, doesn\'t affect play unless you have an automatic turntable. Sticker residue marks on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; G visual very worn and scratched , but plays loud more like G+ , no skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Pressing quality is a bit muffled on other side. Messy pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ (there was a little dirt that is now cleared and there is no longer a skip as shows in clip at 1:52)\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips heard, pen on labels. Side 2 looks quite bad but still plays fine.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , there was a little piece of dirt at 0:45 in clip that is now clear.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG light marks, no skips.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , except a couple little scuffs heard at the start of the first song in clip.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ / fair , no skips. Side 2 has some feelable marks. Staining to B side label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Plays decently though, check longer clip. Small pen on labels.&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , no skips\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , clean labels.&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG / VG , no skips, pen name on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX-\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , no skips, loud pressing. See label pics.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG+\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG , light marks, clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG- to VG+ as per the clip, small pen name on labels and label wear around the edges.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- plays great more of a VG sound quality.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some wear to both labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. see pics of labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / VG , B heard first in clip. See label pics.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , nice copy, more sound quality. Clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , no skips, nice pressing plays loud, small pen on B label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+ , one small mark first 1-2 mins side B lowers grade a tiny bit.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Messy pen both labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- (first 30-60s) to VG+ , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX , see pics for label ': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips. No pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, small sticker on B label\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , other side label is more faded, little pen marks.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , dirt/worn B side label, stamped.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;A is G+ to VG- / B is VG- , no skips. Side B heard first in clip.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; EX / VG+ to EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , small pen on labels and other side label worn.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- no skips. Check full clip. Tiny pen mark on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, pen on other side label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only , coloured vinyl. Small writing on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Pressing has noise on it. Pen on labels. NOTE: no skip at end of the clip, I nudged the deck by accident.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips. Stamp on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;Side A plays G (first 60s) then gradually improves up to about a VG- grade. Side B similar but improves faster playing G+ after about 30s then gradually improving to VG-. Clean labels.&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , though there was a stick at the end of side B (10:55 in clip)\\u003C': ['VG'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , numerous little marks and scuffs and improving. Pen small on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips, nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , the text has faded a bit on both sides.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / G+ to VG- , no skips, plays well. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some wear to the labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , noisy at the start and improving, no skips, pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;FAIR , heavy wear... didn\'t hear any skips... Pen on labels.\\u003C': ['F']}

# %% [markdown]
# Let's remove discrepancies

# %%
for key, value in list(dictionary.items()):
    if len(value) > 1:
        del dictionary[key]

# %%
dictionary
# Out:
# {':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some noise on pressing.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , slight fading/wear to labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp; &nbsp;, no skips. Small pen name on B label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG both sides, no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ / G , no skips. Clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , both labels are a bit stained/discoloured.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG- to VG , clean labels except 1 small white mark side B label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+ , slight hazing to the A side&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , bit noisy on the run-in then plays G+ no skips. Small pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Small pen mark on one label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , some label wear.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , slight hazing and minor warp to edge side 2, not affecting play. Pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG- to VG\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G visual, the play grade is G+ though and is punchy and loud despite marks.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ bordering EX , super nice copy EXCEPT one tiny scuff on the less funky side (heard 1:07-1:20 in clip) causes a few repeat tics/pops. Check label pics.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, small pen name on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ visual , plays VG- . Name sticker top of B side.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG- to VG+&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Shop stamp on A side label.&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+, superficial marks.. See label pics. NOTE this release has a slightly distorted sound on ALL the pressings I have heard, there is no \'clipping\' on my sound file.\\u003C': ['VG+'],
#  ' (visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;poor - very heavy wear, pretty much unplayable. It\'s a filler copy. See pictures for label ': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays with some light noise.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Light label wear/staining&nbsp;\\u003C': ['VG'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG- , numerous light marks and scuffs both sides, nothing major. Check extended clip, sounds quality nice. Small pen name on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX- , see pics for labels\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen on labels.&nbsp;&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , don\'t miss the disco style B side.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;Mostly NM unplayed , however there\'s a little bit of paper stuck in pressing at start of A side (see 2nd pic) causing a few tics, and also a smaller piece stuck in the B side that causes a few lighter tics (listen at 2:08 in clip, it\'s very mild).\\u003C': ['NM'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ (first 30-60s) to VG , no skips. Tiny pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Tiny pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , great copy. Small pen name both sides\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Small pen name on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays at 33rpm\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips, plays loud.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Labels worn and top part ripped with stamped number both sides, SWOL\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. See label pics.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG play grade. Labels worn.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , B heard first in clip - check the surprise rap at 2:22 in the clip !\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;poor / fair , side A has several large sideways scratches that cause repeat skips/sticks, side B is around the G+ grade but also has sticks/skips due to several marks so I didn\'t listen to the whole side.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, pen on labels , B side is the killer side don\'t miss it in the clip\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips. Pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX , sample stamp on side B label\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX stock\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels decent\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small blue marker pen name on other side\'s label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; first 30s VG moving to VG+ . Clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ no skips, numerous little marks and scuffs, plays loud.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG / VG , side B heard first in clip. No skips, there is a few pops from a little mark near start of side A which is why the grade is lower at the start of the side. Label wear and little label rips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , other side has a bit of pen on label\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , smal pen on labels\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy light marks and improving plays quite clean and nice, check label photos.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some superficial marks only\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG , no skips. Labels worn, little pen and some light flaking.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , some light marks and improving. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;plays VG to VG+&nbsp;&nbsp;\\u003C': ['VG'],
#  ' (visual and partial audio grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , see label pics&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , quite heavy wear, plays loud and still sounds decent. Small pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Couple of small tics occasionally.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some noise on pressing on A side.&nbsp;\\u003C': ['VG+'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, many marks and scuffs, may have skips/sticks.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips. poor labels , other side label is worse.\\u003C': ['G'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG- to VG , except B1 G+ , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips , small&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , few little very minor marks start of each side\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , pen marks on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ visually, playing VG+&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips, heavy wear, plays through fine more G+ sonically.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skip, small pen marks both sides.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp; , some superficial marks only. Messy pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very unusual side B don\'t miss the clip!\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX-\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , messy pen on labels, see pics.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG. Small pen on labels.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels worn (see pics)&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , small pen on B label\\u003C': ['G'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , may have skips.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks, small pen on B label. Great ballad B side!\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean.&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG / VG , no skips. B heard first in audio clip, nice clean labels except small pen name top of A side label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , labels faded/worn both sides\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / G+ , no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , shiny with little marks and scuffs. See label pics. Side B heard first in clip.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG, light marks. Small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , nice clean copy, messy pen on both labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , small pen on labels\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , no skips\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , messy pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Quiet pressing especially the \'Guaguanco\' side\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, great copy. Messy pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;visually G+ on side A plays VG- , side B \\"La Murga\\" plays VG- to VG\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Slight pressing noise.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;shiny and clean, few little tiny marks in places , grade VG to VG+\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG , light marks.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , no skips, plays loud.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp; , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+. Small pen on B label.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips, marks and scuffs and improving. Decent labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , small pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ visual. Stick end of A side (no visual marks). Small stamp on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.&nbsp;&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ / VG- as per the clip, see label pics, no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Dirty labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips, plays loud, see pics of labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG / VG , B heard first in the soundclip. Small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only.&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , labels damaged both sides at the top.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ visual, plays VG- no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , great copy. Side B is very slightly off-centre.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ / G+ , no skips. B heard first in clip, clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, messy pen on labels. Some subtle (quiet) strange high noise on side 2 on the pressing.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+ bordering EX.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; first 30-60s each side G+ some scuffing moving to VG+ after that. Messy pen on both labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ (except first 10-20s each side maybe a few marks VG)\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ clean copy, superficial marks only.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks! See pics\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , pen name on both labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, small pen on labels (2 skips heard between 0:49-0:55 have now been cleared)\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , light marks and improving.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;A1-A2 is VG, then VG+ rest side A. Side B1 (listen at 2:00 in clip) is G+ has a few scuffs causing occasional pops/tics and 1 skip (at 2:54 in clip). B2 VG , then rest of side B VG+ light traces. Clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, shiny copy clean looking, a few little tiny marks, plays fine, clean labels.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG-, no skips, pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy. Small pen on B label.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG (30 seconds) to VG+ , small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips , pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, heavy wear, plays without skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear... though it plays through fine with no skips (there was a stick at end of A in the audio clip that is now cleared). Worn labels.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , faint sample stamp.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+, small sticker on B label.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips. clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, side B dull colour, doesn\'t seem to affect play. Small pen on labels.&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG no skips. Plays great.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ (first 30s) moving gradually to VG, no skips. Pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ visual. Plays more VG+ , see pics for label ': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , don\'t miss the killer B side !! at 3:12 in clip.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG+ / VG to VG+ , no skips. Few little scuffs start of first side in clip. Small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG+ , heavy funky B side heard second in the clip. Quiet pressing.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G no skips heard, worn labels with small pen.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , dirt/worn both labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG (30s) to VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G, no skips. Messy pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Loud pressing.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- no skips, a few little noises from circular wear middle side 2. Labels a bit worn.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+&nbsp;&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ first 30s then VG- both sides.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , though a small mark causes a stick middle of side 2 (check 0:39 in clip)\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , plays fine, no skips, faint stamp and marker pen initials on both labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on both labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , clean copy with a few superficial marks.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , clean copy with a few superficial marks. Slight label flaking.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , sample stamp on side B&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ , small pen on the A label, B label clean.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ ,small pen on B label.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , noise on pressing, B side playing very slightly off-centre\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , quite heavy wear, plays fine despite marks, no skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; first 30s VG moving to VG+&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , a few superficial marks only\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX , unplayed stock copy.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear... no skips. Worn labels.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some noise on pressing. Nice copy!&nbsp;\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- first 30s , then improving to VG+\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG , no skips. Pen titles on both sides labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ no skips. Very messy pen on both labels!\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ . Small pen name on labels\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG, nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ a few superficial marks only.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ / G+ as per the clip. no skips\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- no skips. Small pen on labels.\\u003C': ['G+'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;intro/start of A G , then it\'s G+ sound quality all the way after that , has marks and scuffs but plays fine without skips. Clean labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;fair , heavy wear! side heard first in the clip has NO skips and plays better than it looks after the first 30s, the other sides has skips/sticks.\\u003C': ['F'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , some marks and scuffs. Labels have some wear.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+ , great copy. Small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some superficial marks\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; VG+ , a few superficial fait marks only. Small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX / EX-\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG to VG+ , clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See pics/\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ ,see pics for labels&nbsp;\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G+ to VG- , more VG- , no skips, small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ no skips... Heavy wear both sides but playing fine on the second half. WOL\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;EX / VG+ to EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Pen on both labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , nice copy, playing fair clean and the A side playing above grade. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG, light marks. Slight haze to vinyl\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G visual. Plays G+ , 1 stick end of the B side.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , see pics for label ': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See label pics at top.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. Other side has a sticker removal mark top of label.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips. Pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ (skip at 1:01 has now been cleared)\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , plays with light noise other side.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG-&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG to VG+ , small pen name on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , sample stamp on B label\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , very clean! See pics\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips, heavy wear, plays through fine. SWOL\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; &nbsp; &nbsp;G+ to VG- 1 skip heard side 1. EDGE CHIP second photo, doesn\'t affect play unless you have an automatic turntable. Sticker residue marks on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; G visual very worn and scratched , but plays loud more like G+ , no skips.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Pressing quality is a bit muffled on other side. Messy pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ (there was a little dirt that is now cleared and there is no longer a skip as shows in clip at 1:52)\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , nice copy\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips heard, pen on labels. Side 2 looks quite bad but still plays fine.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , there was a little piece of dirt at 0:45 in clip that is now clear.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG light marks, no skips.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , except a couple little scuffs heard at the start of the first song in clip.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ / fair , no skips. Side 2 has some feelable marks. Staining to B side label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ no skips. Plays decently though, check longer clip. Small pen on labels.&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , no skips\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , clean labels.&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG / VG , no skips, pen name on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX-\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , no skips, loud pressing. See label pics.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG / VG+\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG , light marks, clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ / VG- to VG+ as per the clip, small pen name on labels and label wear around the edges.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- plays great more of a VG sound quality.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , some wear to both labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks. see pics of labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / VG , B heard first in clip. See label pics.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , nice copy, more sound quality. Clean labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ , no skips, nice pressing plays loud, small pen on B label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / VG to VG+ , one small mark first 1-2 mins side B lowers grade a tiny bit.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips. Messy pen both labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- (first 30-60s) to VG+ , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ / EX , see pics for label ': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G , no skips. No pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only. Small pen on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks, small sticker on B label\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- no skips.&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , other side label is more faded, little pen marks.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , dirt/worn B side label, stamped.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;A is G+ to VG- / B is VG- , no skips. Side B heard first in clip.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; EX / VG+ to EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips , small pen on labels and other side label worn.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- no skips. Check full clip. Tiny pen mark on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- , clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, pen on other side label.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , superficial marks only , coloured vinyl. Small writing on labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG, light marks. Pressing has noise on it. Pen on labels. NOTE: no skip at end of the clip, I nudged the deck by accident.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;strong VG to VG+ , small pen on labels.\\u003C': ['VG'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG&nbsp;\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G to G+ , no skips. Stamp on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;Side A plays G (first 60s) then gradually improves up to about a VG- grade. Side B similar but improves faster playing G+ after about 30s then gradually improving to VG-. Clean labels.&nbsp;\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG to VG+ , though there was a stick at the end of side B (10:55 in clip)\\u003C': ['VG'],
#  ' (partial audio and visual grade):&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , numerous little marks and scuffs and improving. Pen small on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ to VG- , no skips, nice labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- to VG , the text has faded a bit on both sides.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG- / G+ to VG- , no skips, plays well. Clean labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; EX\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;VG+ , some wear to the labels.\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;G+ no skips, small pen on labels.\\u003C': ['G+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; G to G+ , noisy at the start and improving, no skips, pen on labels.\\u003C': ['G'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp; VG+\\u003C': ['VG+'],
#  ':&nbsp;\\u003C/b><span style=\\"font-family: Arial; font-size: 14pt;\\">&nbsp; &nbsp;FAIR , heavy wear... didn\'t hear any skips... Pen on labels.\\u003C': ['F']}

# %% [markdown]
# So, now we can map the conditions to the dataframe!

# %%
wills_audio['A_first_part'] = wills_audio['condition'].map(dictionary)

# %% [markdown]
# Let's have a look..

# %%
wills_audio.head()
# Out:
#    Unnamed: 0                                               Link  \
# 0           0  http://www.watchcount.com/go/?item=11623035299...
# 1           1  http://www.watchcount.com/go/?item=11623035299...
# 2           2  http://www.watchcount.com/go/?item=11623035039...
# 3           3  http://www.watchcount.com/go/?item=11623034962...
# 4           4  http://www.watchcount.com/go/?item=11623034725...
#
#                                                Title  \
# 0  Ahmed al-Jaberi - Rare SUDAN Arabic Afro 45 / ...
# 1  Ahmed al-Jaberi - Rare SUDAN Arabic Afro 45 / ...
# 2  Mohamed Mirghani - Rare SUDAN Arabic Afro 45 /...
# 3  Tayeb Abdullah ? - Rare SUDAN Arabic Afro 45 /...
# 4  Ibrahim Awad - Ya Zaman - Rare SUDAN Arabic Af...
#
#                                            condition  \
# 0                                                NaN
# 1  :&nbsp;\u003C/b><span style=\"font-family: Ari...
# 2  :&nbsp;\u003C/b><span style=\"font-family: Ari...
# 3  :&nbsp;\u003C/b><span style=\"font-family: Ari...
# 4  :&nbsp;\u003C/b><span style=\"font-family: Ari...
#
#                    mp3_path A_first_part
# 0                       NaN          NaN
# 1  ./output/audio2/7595.mp3        [VG+]
# 2  ./output/audio2/5576.mp3        [VG+]
# 3  ./output/audio2/7000.mp3         [VG]
# 4  ./output/audio2/4374.mp3        [VG+]

# %% [markdown]
# We need to select the only element from the list.

# %%
wills_audio["A_first_part"] = wills_audio["A_first_part"].apply(lambda x: x[0] if pd.notna(x) else x)

# %%
wills_audio["A_first_part"].value_counts()
# Out:
# A_first_part
# VG+    134
# G+     110
# VG      78
# G       37
# F        6
# NM       1
# Name: count, dtype: int64

# %% [markdown]
# We have a class imbalance that we must take into account. Let's save the dataframe in a new file.

# %%
wills_audio.to_csv("./output/wills_audio_annotated.csv")
